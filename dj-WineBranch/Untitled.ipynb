# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import datetime
import requests
import csv
from matplotlib import pyplot as plt

# File to Load 
wine_data = "Resources/Wine_Bottled_2019.csv"
per_capita = "Resources/per_capita_consumption_states_1977_2018_clean.csv"
population = "Resources/CDCPopulationGender.csv"

# Read Wine Production File and store into Pandas data frame
wine_data = pd.read_csv(wine_data)
wine_df = wine_data
wine_df.head(1000)
# Out:
#           State  # of Bottled Still Wines  # of Bottled Effervescence Wines  \
# 0       Alabama                     30153                               200
# 1        Alaska                      5247                                 0
# 2       Arizona                     80784                              2059
# 3      Arkansas                     24197                                 0
# 4    California                  39007466                           1110404
# ..          ...                       ...                               ...
# 540   Wisconsin                    353647                               496
# 541   Wisconsin                    156990                                 0
# 542   Wisconsin                    132404                              1063
# 543   Wisconsin                    257117                               483
# 544   Wisconsin                    353154                               227
#
#          Month  Year
# 0     December   2019
# 1     December   2019
# 2     December   2019
# 3     December   2019
# 4     December   2019
# ..         ...    ...
# 540      March   2019
# 541        May   2019
# 542   November   2019
# 543    October   2019
# 544  September   2019
#
# [545 rows x 5 columns]

# %%
wine_df.columns = ['State', 'Still', 'Effervescence', 'Month', 'Year']
wine_df.dtypes
# Out:
# State            object
# Still             int64
# Effervescence     int64
# Month            object
# Year              int64
# dtype: object

# %%
wine_df.plot.line()
# Out:
# <AxesSubplot:>

# %%
#month_group = effervescence_wine.groupby("Month")
month_group = wine_df.groupby(by=["State"]).min()
month_group
# Out:
#                         Still  Effervescence     Month  Year
# State
# Alabama                     0              0     April  2019
# Alaska                      0              0     April  2019
# Arizona                     0              0  December  2019
# Arkansas                 1190              0     April  2019
# California            3792417              0     April  2019
# Colorado                20645              0     April  2019
# Connecticut              1183              0     April  2019
# Delaware                    0              0     April  2019
# District of Columbia        0              0  December  2019
# Florida                 42887              0     April  2019
# Georgia                  4281              0     April  2019
# Hawaii                      0              0     April  2019
# Idaho                       0              0     April  2019
# Illinois                69420              0     April  2019
# Indiana                 34251              0     April  2019
# Iowa                     4074              0     April  2019
# Kansas                   1133              0     April  2019
# Kentucky                 9549              0     April  2019
# Louisiana                   0              0     April  2019
# Maine                       0              0     April  2019
# Maryland                 4381              0     April  2019
# Massachusetts           61778              0     April  2019
# Michigan                83927              0     April  2019
# Minnesota                 133              0     April  2019
# Mississippi                 0              0     April  2019
# Missouri                 5842              0     April  2019
# Montana                     0              0     April  2019
# Nebraska                    0              0     April  2019
# Nevada                      0              0     April  2019
# New Hampshire               0              0     April  2019
# New Jersey              50241              0     April  2019
# New Mexico              14300              0     April  2019
# New York              1782416          20158     April  2019
# North Carolina         198781              0     April  2019
# North Dakota              271              0  December  2019
# Ohio                    55525              0     April  2019
# Oklahoma                    0              0     April  2019
# Oregon                 196881              0     April  2019
# Pennsylvania           871861              0     April  2019
# Rhode Island              120              0  December  2019
# South Carolina              0              0     April  2019
# South Dakota            20281              0  December  2019
# Tennessee               19969              0     April  2019
# Texas                  103015              0     April  2019
# Utah                      632              0  December  2019
# Vermont                176893              0     April  2019
# Virginia                58401              0     April  2019
# Washington             179074              0     April  2019
# West Virginia               0              0     April  2019
# Wisconsin              106965              0     April  2019
# Wyoming                  5598              0  December  2019

# %%
#month_group = effervescence_wine.groupby("Month")
month_group.groupby(['Month','State'])

# %%
plot.line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-085a6c0d5d27> in <module>
# ----> 1 plot.line()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'line'
