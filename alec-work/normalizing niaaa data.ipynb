# %%
import pandas as pd
import numpy as np

# %%
niaaa_path = "../resources/niaaa_data_txt_to_csv.csv"
niaaa_df = pd.read_csv(niaaa_path,header=None)
niaaa_df
# Out:
#          0   1   2           3          4          5      6   7          8   \
# 0      1970   1   1     3863000    1738350    2499000   6956   9    2020000
# 1      1970   1   2     1412000     225920    2499000    904   9    2020000
# 2      1970   1   3    33098000    1489410    2499000   5960  10    2020000
# 3      1970   1   4           .    3453680    2499000  13820  10    2020000
# 4      1970   2   1      945000     425250     205000  20744   1     165000
# ...     ...  ..  ..         ...        ...        ...    ...  ..        ...
# 10972  2018  99   1   570983458  234674202  270449061   8677   .  240910947
# 10973  2018  99   2   913944969  117898901  270449061   4359   .  240910947
# 10974  2018  99   3  6318315520  284324198  270449061  10513   .  240910947
# 10975  2018  99   4           .  636897302  270449061  23550   .  240910947
# 10976  2018  99   4           .  636897302  270449061  23550   .  240910947
#
#           9   10 11   12         13
# 0       8606   9  .    .          .
# 1       1118   9  .    .          .
# 2       7373  10  .    .          .
# 3      17097  10  .    .          .
# 4      25773   1  .    .          .
# ...      ...  .. ..  ...        ...
# 10972   9741   .  .  384  219257648
# 10973   4894   .  .  117  106931561
# 10974  11802   .  .   48  303279145
# 10975  26437   .  .    .  629468354
# 10976  26437   .  .    .  629468354
#
# [10977 rows x 14 columns]

# %%
niaaa_col_path = "../resources/NIH NIAAA CSV FILE - COLUMN HEADERS.csv"
niaaa_col_df = pd.read_csv(niaaa_col_path,header=None)
niaaa_col_df
# Out:
#      0                                                  1
# 0    1                       Year (4-digit calendar year)
# 1    2  Geographic ID code (FIPS code, see specificati...
# 2    3         Type of beverage (see specification below)
# 3    4                                Gallons of beverage
# 4    5              Gallons of ethanol (absolute alcohol)
# 5    6                      Population (age 14 and older)
# 6    7     Gallons of ethanol per capita age 14 and older
# 7    8  Decile for per capita consumption age 14 and o...
# 8    9                      Population (age 21 and older)
# 9   10     Gallons of ethanol per capita age 21 and older
# 10  11  Decile for per capita consumption age 21 and o...
# 11  12                                Type of data source
# 12  13               Time-varying alcohol by volume (ABV)
# 13  14   Gallons of ethanol derived from time-varying ABV

# %%
niaaa_columns = niaaa_col_df[1]
niaaa_columns
# Out:
# 0                          Year (4-digit calendar year)
# 1     Geographic ID code (FIPS code, see specificati...
# 2            Type of beverage (see specification below)
# 3                                   Gallons of beverage
# 4                 Gallons of ethanol (absolute alcohol)
# 5                         Population (age 14 and older)
# 6        Gallons of ethanol per capita age 14 and older
# 7     Decile for per capita consumption age 14 and o...
# 8                         Population (age 21 and older)
# 9        Gallons of ethanol per capita age 21 and older
# 10    Decile for per capita consumption age 21 and o...
# 11                                  Type of data source
# 12                 Time-varying alcohol by volume (ABV)
# 13     Gallons of ethanol derived from time-varying ABV
# Name: 1, dtype: object

# %%
niaaa_df.columns = [niaaa_columns]
niaaa_df
# Out:
# 1     Year (4-digit calendar year)  \
# 0                             1970
# 1                             1970
# 2                             1970
# 3                             1970
# 4                             1970
# ...                            ...
# 10972                         2018
# 10973                         2018
# 10974                         2018
# 10975                         2018
# 10976                         2018
#
# 1     Geographic ID code (FIPS code, see specification below)  \
# 0                                                      1
# 1                                                      1
# 2                                                      1
# 3                                                      1
# 4                                                      2
# ...                                                  ...
# 10972                                                 99
# 10973                                                 99
# 10974                                                 99
# 10975                                                 99
# 10976                                                 99
#
# 1     Type of beverage (see specification below) Gallons of beverage  \
# 0                                              1             3863000
# 1                                              2             1412000
# 2                                              3            33098000
# 3                                              4                   .
# 4                                              1              945000
# ...                                          ...                 ...
# 10972                                          1           570983458
# 10973                                          2           913944969
# 10974                                          3          6318315520
# 10975                                          4                   .
# 10976                                          4                   .
#
# 1     Gallons of ethanol (absolute alcohol) Population (age 14 and older)  \
# 0                                   1738350                       2499000
# 1                                    225920                       2499000
# 2                                   1489410                       2499000
# 3                                   3453680                       2499000
# 4                                    425250                        205000
# ...                                     ...                           ...
# 10972                             234674202                     270449061
# 10973                             117898901                     270449061
# 10974                             284324198                     270449061
# 10975                             636897302                     270449061
# 10976                             636897302                     270449061
#
# 1     Gallons of ethanol per capita age 14 and older  \
# 0                                               6956
# 1                                                904
# 2                                               5960
# 3                                              13820
# 4                                              20744
# ...                                              ...
# 10972                                           8677
# 10973                                           4359
# 10974                                          10513
# 10975                                          23550
# 10976                                          23550
#
# 1     Decile for per capita consumption age 14 and older  \
# 0                                                      9
# 1                                                      9
# 2                                                     10
# 3                                                     10
# 4                                                      1
# ...                                                  ...
# 10972                                                  .
# 10973                                                  .
# 10974                                                  .
# 10975                                                  .
# 10976                                                  .
#
# 1     Population (age 21 and older)  \
# 0                           2020000
# 1                           2020000
# 2                           2020000
# 3                           2020000
# 4                            165000
# ...                             ...
# 10972                     240910947
# 10973                     240910947
# 10974                     240910947
# 10975                     240910947
# 10976                     240910947
#
# 1     Gallons of ethanol per capita age 21 and older  \
# 0                                               8606
# 1                                               1118
# 2                                               7373
# 3                                              17097
# 4                                              25773
# ...                                              ...
# 10972                                           9741
# 10973                                           4894
# 10974                                          11802
# 10975                                          26437
# 10976                                          26437
#
# 1     Decile for per capita consumption age 21 and older Type of data source  \
# 0                                                      9                   .
# 1                                                      9                   .
# 2                                                     10                   .
# 3                                                     10                   .
# 4                                                      1                   .
# ...                                                  ...                 ...
# 10972                                                  .                   .
# 10973                                                  .                   .
# 10974                                                  .                   .
# 10975                                                  .                   .
# 10976                                                  .                   .
#
# 1     Time-varying alcohol by volume (ABV)  \
# 0                                        .
# 1                                        .
# 2                                        .
# 3                                        .
# 4                                        .
# ...                                    ...
# 10972                                  384
# 10973                                  117
# 10974                                   48
# 10975                                    .
# 10976                                    .
#
# 1     Gallons of ethanol derived from time-varying ABV
# 0                                                    .
# 1                                                    .
# 2                                                    .
# 3                                                    .
# 4                                                    .
# ...                                                ...
# 10972                                        219257648
# 10973                                        106931561
# 10974                                        303279145
# 10975                                        629468354
# 10976                                        629468354
#
# [10977 rows x 14 columns]

# %%
niaaa_df_norm = niaaa_df.rename(columns = {"Geographic ID code (FIPS code, see specification below)" : "Geo Code"})
niaaa_df_norm
# Out:
# 1     Year (4-digit calendar year) Geo Code  \
# 0                             1970        1
# 1                             1970        1
# 2                             1970        1
# 3                             1970        1
# 4                             1970        2
# ...                            ...      ...
# 10972                         2018       99
# 10973                         2018       99
# 10974                         2018       99
# 10975                         2018       99
# 10976                         2018       99
#
# 1     Type of beverage (see specification below) Gallons of beverage  \
# 0                                              1             3863000
# 1                                              2             1412000
# 2                                              3            33098000
# 3                                              4                   .
# 4                                              1              945000
# ...                                          ...                 ...
# 10972                                          1           570983458
# 10973                                          2           913944969
# 10974                                          3          6318315520
# 10975                                          4                   .
# 10976                                          4                   .
#
# 1     Gallons of ethanol (absolute alcohol) Population (age 14 and older)  \
# 0                                   1738350                       2499000
# 1                                    225920                       2499000
# 2                                   1489410                       2499000
# 3                                   3453680                       2499000
# 4                                    425250                        205000
# ...                                     ...                           ...
# 10972                             234674202                     270449061
# 10973                             117898901                     270449061
# 10974                             284324198                     270449061
# 10975                             636897302                     270449061
# 10976                             636897302                     270449061
#
# 1     Gallons of ethanol per capita age 14 and older  \
# 0                                               6956
# 1                                                904
# 2                                               5960
# 3                                              13820
# 4                                              20744
# ...                                              ...
# 10972                                           8677
# 10973                                           4359
# 10974                                          10513
# 10975                                          23550
# 10976                                          23550
#
# 1     Decile for per capita consumption age 14 and older  \
# 0                                                      9
# 1                                                      9
# 2                                                     10
# 3                                                     10
# 4                                                      1
# ...                                                  ...
# 10972                                                  .
# 10973                                                  .
# 10974                                                  .
# 10975                                                  .
# 10976                                                  .
#
# 1     Population (age 21 and older)  \
# 0                           2020000
# 1                           2020000
# 2                           2020000
# 3                           2020000
# 4                            165000
# ...                             ...
# 10972                     240910947
# 10973                     240910947
# 10974                     240910947
# 10975                     240910947
# 10976                     240910947
#
# 1     Gallons of ethanol per capita age 21 and older  \
# 0                                               8606
# 1                                               1118
# 2                                               7373
# 3                                              17097
# 4                                              25773
# ...                                              ...
# 10972                                           9741
# 10973                                           4894
# 10974                                          11802
# 10975                                          26437
# 10976                                          26437
#
# 1     Decile for per capita consumption age 21 and older Type of data source  \
# 0                                                      9                   .
# 1                                                      9                   .
# 2                                                     10                   .
# 3                                                     10                   .
# 4                                                      1                   .
# ...                                                  ...                 ...
# 10972                                                  .                   .
# 10973                                                  .                   .
# 10974                                                  .                   .
# 10975                                                  .                   .
# 10976                                                  .                   .
#
# 1     Time-varying alcohol by volume (ABV)  \
# 0                                        .
# 1                                        .
# 2                                        .
# 3                                        .
# 4                                        .
# ...                                    ...
# 10972                                  384
# 10973                                  117
# 10974                                   48
# 10975                                    .
# 10976                                    .
#
# 1     Gallons of ethanol derived from time-varying ABV
# 0                                                    .
# 1                                                    .
# 2                                                    .
# 3                                                    .
# 4                                                    .
# ...                                                ...
# 10972                                        219257648
# 10973                                        106931561
# 10974                                        303279145
# 10975                                        629468354
# 10976                                        629468354
#
# [10977 rows x 14 columns]

# %%
niaaa_geo_code_path = "../resources/niaaa_data_geographic_id_code.csv"
niaaa_geo_code_df = pd.read_csv(niaaa_geo_code_path,header=None)
niaaa_geo_code_df.columns = ["code","state_region"]
niaaa_geo_code_df
# Out:
#     code          state_region
# 0      1               Alabama
# 1      2                Alaska
# 2      4               Arizona
# 3      5              Arkansas
# 4      6            California
# 5      8              Colorado
# 6      9           Connecticut
# 7     10              Delaware
# 8     11  District of Columbia
# 9     12               Florida
# 10    13               Georgia
# 11    15                Hawaii
# 12    16                 Idaho
# 13    17              Illinois
# 14    18               Indiana
# 15    19                  Iowa
# 16    20                Kansas
# 17    21              Kentucky
# 18    22             Louisiana
# 19    23                 Maine
# 20    24              Maryland
# 21    25         Massachusetts
# 22    26              Michigan
# 23    27             Minnesota
# 24    28           Mississippi
# 25    29              Missouri
# 26    30               Montana
# 27    31              Nebraska
# 28    32                Nevada
# 29    33         New Hampshire
# 30    34            New Jersey
# 31    35            New Mexico
# 32    36              New York
# 33    37        North Carolina
# 34    38          North Dakota
# 35    39                  Ohio
# 36    40              Oklahoma
# 37    41                Oregon
# 38    42          Pennsylvania
# 39    44          Rhode Island
# 40    45        South Carolina
# 41    46          South Dakota
# 42    47             Tennessee
# 43    48                 Texas
# 44    49                  Utah
# 45    50               Vermont
# 46    51              Virginia
# 47    53            Washington
# 48    54         West Virginia
# 49    55             Wisconsin
# 50    56               Wyoming
# 51    91      Northeast Region
# 52    92        Midwest Region
# 53    93          South Region
# 54    94           West Region
# 55    99         United States

# %%
niaaa_df_geo = pd.merge(niaaa_df_norm, niaaa_geo_code_df, left_on ="Geo Code",
                             right_on="code", how="left")
niaaa_df_geo
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8274fa8d92a1> in <module>
# ----> 1 niaaa_df_geo = pd.merge(niaaa_df_norm, niaaa_geo_code_df, left_on ="Geo Code",
#       2                              right_on="code", how="left")
#       3 niaaa_df_geo
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1016                         right_keys.append(rk)
#    1017                     if lk is not None:
# -> 1018                         left_keys.append(left._get_label_or_level_values(lk))
#    1019                         join_names.append(lk)
#    1020                     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1557         if self._is_label_reference(key, axis=axis):
#    1558             self._check_label_or_level_ambiguity(key, axis=axis)
# -> 1559             values = self.xs(key, axis=other_axes[0])._values
#    1560         elif self._is_level_reference(key, axis=axis):
#    1561             values = self.axes[axis].get_level_values(key)._values
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3483
#    3484         if axis == 1:
# -> 3485             return self[key]
#    3486
#    3487         index = self.index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2876                 if self.columns.nlevels > 1:
#    2877                     return self._getitem_multilevel(key)
# -> 2878                 return self._get_item_cache(key)
#    2879
#    2880         # Do we have a slicer (on rows)?
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    3539
#    3540             loc = self.columns.get_loc(item)
# -> 3541             values = self._mgr.iget(loc)
#    3542             res = self._box_col_values(values, loc)
#    3543
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in iget(self, i)
#     986         Return the data as a SingleBlockManager.
#     987         """
# --> 988         block = self.blocks[self.blknos[i]]
#     989         values = block.iget(self.blklocs[i])
#     990
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
niaaa_df['state_region'] = niaaa_df.lookup(df['best'])
